# %%
import matplotlib.pyplot as py

# %%
pred = open(r"ill_move_prop.txt","r")

# %%
s = pred.readlines()

# %%
y = []
for i in range(len(s)) :
    y.append(float(s[i]))

# %%
x = range(len(s))

# %%
py.plot(x, y)
